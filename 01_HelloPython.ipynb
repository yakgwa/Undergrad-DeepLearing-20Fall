# %% [markdown]
# ## Python tutorial #1

# %% [markdown]
# 본 페이지는 한림대학교 710231(딥러닝이해및응용) 수업에서 학생들의 Python 학습을 위해 만든 페이지입니다

# %% [markdown]
# # Hello World !

# %%
print('Hello World')
print('Hello World {} + {} = {}'.format(2, 3, 2+3))
# Out:
# Hello World
# Hello World 2 + 3 = 5

# %% [markdown]
# # Basic data types

# %%
x = 3
print(type(x)) # Prints "<class 'int'>"
print(x) # Prints "3"
# Out:
# <class 'int'>
# 3

# %%
print(x + 1) # Addition; prints "4"
print(x - 1) # Subtraction; prints "2"
print(x * 2) # Multiplication; prints "6"
print(x ** 2) # Exponentiation; prints "9"
# Out:
# 4
# 2
# 6
# 9

# %% [markdown]
# # For statement

# %%
A = range(5)
print(A)
# Out:
# range(0, 5)

# %%
print(A[2])
# Out:
# 2

# %%
for i in range(5):
 #print(i, A[i])
 print('{} ----- {}'.format(i, A[i]))
# Out:
# 0 ----- 0
# 1 ----- 1
# 2 ----- 2
# 3 ----- 3
# 4 ----- 4

# %% [markdown]
# exercise

# %% [markdown]
# 구구단을 작성하시오(아래 코드를 수정하시오)

# %%
for i in range(8): 
  print('{}단'.format(i+2))
  for j in range(9): 
    c = (i+2)*(j+1)
    print('{} * {} = {}'.format(i+2, j+1, c))
# Out:
# 2단
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 3단
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 4단
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 5단
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 6단
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
# 7단
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 8단
# 8 * 1 = 8
# 8 * 2 = 16
# 8 * 3 = 24
# 8 * 4 = 32
# 8 * 5 = 40
# 8 * 6 = 48
# 8 * 7 = 56
# 8 * 8 = 64
# 8 * 9 = 72
# 9단
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81

# %% [markdown]
# # Operators

# %%
print((1, 2, 3) * 3)
print([1, 2, 3] * 3)
print("Hello "*3)
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# Hello Hello Hello

# %% [markdown]
# # Containers
# Python includes several built-in container types: lists, dictionaries, sets, and tuples.

# %% [markdown]
# # Tuple
# A simple immutable (변경할 수 없는, 불변의) ordered sequence of items

# %%
# -*- coding: utf-8 -*-
# creating a tuple
months = ('January','February','March','April','May','June',\
'July','August','September','October','November','December')
print(months[0])
print("index of 7 ==> " , months[7])
# Out:
# January
# index of 7 ==>  August

# %% [markdown]
# To print one by one

# %%
# iterate through them:
for item in months:
 print (item)

# %%
t = ('john', 32, (2,3,4,5), 'hello')
print(t)
print(t[2])
print(t[2][1])
print(t[:2]) # index 포함 X
print(t[2:]) # index 포함 O
print(t[-1])
print(t[-2])

# %% [markdown]
# # List
# Mutable (바꿀수 있는, 변경가능한) ordered sequence of items of mixed types

# %%
li = ['hallym', 1, 3.141572, 'hello']
print(li)
# Out:
# ['hallym', 1, 3.141572, 'hello']

# %%
li[1] = 45
print(li)
# Out:
# ['hallym', 45, 3.141572, 'hello']

# %%
li.append('September')
print(li)
# Out:
# ['hallym', 45, 3.141572, 'hello', 'September']

# %% [markdown]
# + 비어있는 리스트 만들기

# %%
v = [] # 작업을 실행하기 전 빈 공간

# %% [markdown]
# + 비어있는 리스트에 값 추가하기

# %%
for i in range(0,3):
 v.append(i*5)
 print(i, v)
# Out:
# 0 [0]
# 1 [0, 5]
# 2 [0, 5, 10]

# %% [markdown]
# # + 연산자

# %%
print((1, 2, 3) + (4, 5, 6))
print([1, 2, 3] + [4, 5, 6])
print("Hello" + " " + "World")
# Out:
# (1, 2, 3, 4, 5, 6)
# [1, 2, 3, 4, 5, 6]
# Hello World

# %% [markdown]
# # * 연산자
# The *operator produces a new tuple, list, or string that "repeats" thd original content.

# %%
y = 2.5
print(type(y)) # Prints "<class 'float'>"
print(y, y + 1, y * 2, y ** 2) # Prints "2.5 3.5 5.0 6.25"
# Out:
# <class 'float'>
# 2.5 3.5 5.0 6.25

# %% [markdown]
# # Enumeration(열거하기)

# %%
for i, val in enumerate(v):
 print('{} ---> {}'.format(i, val))
# Out:
# 0 ---> 0
# 1 ---> 5
# 2 ---> 10

# %%
v2 = [ 'A', 'B', 'C', '0', '1', '2', '3']
print(v2)
# Out:
# ['A', 'B', 'C', '0', '1', '2', '3']

# %%
for i, val in enumerate(v2):
 print('{} ---> {}'.format(i, val))
# Out:
# 0 ---> A
# 1 ---> B
# 2 ---> C
# 3 ---> 0
# 4 ---> 1
# 5 ---> 2
# 6 ---> 3
