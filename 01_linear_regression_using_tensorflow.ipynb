# %% [markdown]
# Linear regression 을 학습하며, 기계학습의 원리 및 TensorFlow 를 익히는 notebook 입니다.

# %% [markdown]
# **라이브러리 Import 하기**

# %%
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **X and Y data**

# %%
x_train = [1, 2, 3]

y_train = [2+0.1, 4-0.3, 6+0.15] # 약간의 noise 추가

# 다음의 것들도 해보시오
#y_train = [2, 4, 6] # 그냥 x_train 에 2배 곱해서 생성
#y_train = [3, 5, 7]

# %% [markdown]
# **Initialization**

# %%
useRandom = False

# %%
if useRandom:
    W = tf.Variable(tf.random_normal([1]), name='weight')
    b = tf.Variable(tf.random_normal([1]), name='bias')
else:
    w0 = 7.0;
    b0 = 5.0;

    W = tf.Variable(w0*tf.ones([1]), name='weight')
    b = tf.Variable(b0*tf.ones([1]), name='bias')

# %% [markdown]
# **Our hypothesis XW+b**

# %%
hypothesis = x_train * W + b

# %% [markdown]
# **cost/loss function 정의하기**
# * loss of one training example :
# $$loss = \mathcal{L}(\hat{y}, y) = (\hat y^{(i)} - y^{(i)})^2 \tag{1}$$

# %%
loss = tf.reduce_mean(tf.square(hypothesis - y_train))

# %% [markdown]
# **Optimizer**

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(loss)

# %% [markdown]
# **Launch the graph in a session**

# %%
sess = tf.Session()

# %% [markdown]
# **Initializes global variables in the graph.**

# %%
sess.run(tf.global_variables_initializer())

# %%
nb_epoch = 2001
vloss = []
vw = []
vb = []

for step in range(nb_epoch):
    sess.run(train)
    loss1 = sess.run(loss)
    vloss.append(loss1)
    vw.append(w1)
    vb.append(b1)
    
    if step % 200 == 0: # 200번마다
        w1 = sess.run(W)[0] # 기울기
        b1 = sess.run(b)[0] # bias
        
        print(step,'\t', loss1,'\t', w1,'\t', b1)
# Out:
# 0 	 191.49957 	 6.333 	 4.6996665
# 200 	 0.35716426 	 1.3710524 	 1.41991
# 400 	 0.16119462 	 1.6209003 	 0.8519472
# 600 	 0.08636397 	 1.7752908 	 0.5009811
# 800 	 0.057789873 	 1.870695 	 0.2841049
# 1000 	 0.046878874 	 1.9296489 	 0.15008868
# 1200 	 0.042712513 	 1.966079 	 0.06727501
# 1400 	 0.041121617 	 1.9885904 	 0.016101157
# 1600 	 0.040514123 	 2.0025008 	 -0.015521015
# 1800 	 0.040282175 	 2.011097 	 -0.035061836
# 2000 	 0.0401936 	 2.016409 	 -0.047137048

# %%
plt.plot(vloss[:100],'.-')
plt.xlabel('epoch')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
plt.plot(vloss)

# %% [markdown]
# TODO : w,b의 epoch에 따른 변화 그래프 넣기

# %%
plt.plot(vw,'.-')

# %%
plt.plot(vb,'.-')

# %% [markdown]
# **학습완료**

# %%
w1 = sess.run(W)[0] # 기울기
b1 = sess.run(b)[0] # bias

# %% [markdown]
# 출력해보기

# %%
print(w1, b1)

str1 = 'y = ' + str(w1) +'x + ' + str(b1)
print(str1)
# Out:
# 2.016409 -0.047137048
# y = 2.016409x + -0.047137048

# %%
plt.figure(figsize=(6,4)) # figsize를 바꾸어보세요
plt.plot(x_train, y_train,'o') #train data 그리기

# 직선 그래프를 그리기 위한 코드
# 그래프의 x좌표를 일정 간격으로 설정함
x1 = np.linspace(np.min(x_train)-1, np.max(x_train)+1)
y1 = w1*x1 + b1
plt.plot(x1, y1)

plt.grid() # 격자
#plt.axis((np.min(x_train) - 1, np.max(x_train) + 1, np.min(y_train) - 1, np.max(y_train) + 1))
plt.title(str1)
# Out:
# Text(0.5, 1.0, 'y = 2.016409x + -0.047137048')

# %% [markdown]
# ### 스스로 해보기

# %%
아래 부분을 수정해서 처음부터 다시 진행해보기 바랍니다. 

* 예1) 노이즈를 다르게 준다
```
x_train = [1, 2, 3]
y_train = [2+0.1, 4-0.3, 6+0.15] # 약간의 noise 추가
```
* 예2) 데이터의 갯수를 지금은 네 개의 점으로 했으나 더 늘려서도 해본다.

* 예3) 데이터의 모델을 현재는 y=2x+0 으로 해서 만들었으나, 바꾸어본다.
```
y=3x-5 
y=1.2x + 3
```

* 예4) 초기값인 w0, b0를 다르게 설정해본다.
```
w0 = 7.0;
b0 = 5.0;
```

# %%
x_train = [1, 3, 5, 7, 9]

y_train = [3+0.15, 9-0.35, 15+0.45, 21+0.15, 27+0.55] # 약간의 noise 추가

# %%
#W = tf.Variable(tf.random_normal([1]), name='weight')
#b = tf.Variable(tf.random_normal([1]), name='bias')
w0 = 9.0;
b0 = 3.0;

W = tf.Variable(w0*tf.ones([1]), name='weight')
b = tf.Variable(b0*tf.ones([1]), name='bias')

# %%
hypothesis = x_train * W + b

# %%
loss = tf.reduce_mean(tf.square(hypothesis - y_train))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(loss)

# %%
sess = tf.Session()

# %%
sess.run(tf.global_variables_initializer())

# %%
nb_epoch = 2001
vloss = []
vw = []
vb = []

for step in range(nb_epoch):
    sess.run(train)
    loss1 = sess.run(loss)
    vloss.append(loss1)
    vw.append(w1)
    vb.append(b1)
    
    if step % 200 == 0: # 200번마다
        w1 = sess.run(W)[0] # 기울기
        b1 = sess.run(b)[0] # bias
        
        print(step,'\t', loss1,'\t', w1,'\t', b1)
# Out:
# 0 	 144.32205 	 4.7694 	 2.3438
# 200 	 0.23507233 	 2.9370356 	 0.70350015
# 400 	 0.090095565 	 3.0155125 	 0.18927136
# 600 	 0.06841292 	 3.0458617 	 -0.009595188
# 800 	 0.06517051 	 3.0575986 	 -0.08650231
# 1000 	 0.06468534 	 3.0621376 	 -0.11624444
# 1200 	 0.064612985 	 3.0638928 	 -0.12774654
# 1400 	 0.06460214 	 3.0645719 	 -0.13219467
# 1600 	 0.064600244 	 3.0648344 	 -0.13391475
# 1800 	 0.06460018 	 3.064936 	 -0.13458003
# 2000 	 0.06460004 	 3.064975 	 -0.13483758

# %%
plt.plot(vloss[:100],'.-')
plt.xlabel('epoch')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
plt.plot(vloss)

# %%
w1 = sess.run(W)[0] # 기울기
b1 = sess.run(b)[0] # bias

# %%
print(w1, b1)

str1 = 'y = ' + str(w1) +'x + ' + str(b1)
print(str1)
# Out:
# 3.064975 -0.13483758
# y = 3.064975x + -0.13483758

# %%
plt.figure(figsize=(6,4)) # figsize를 바꾸어보세요
plt.plot(x_train, y_train,'o') #train data 그리기

# 직선 그래프를 그리기 위한 코드
# 그래프의 x좌표를 일정 간격으로 설정함
x1 = np.linspace(np.min(x_train)-1, np.max(x_train)+1)
y1 = w1*x1 + b1
plt.plot(x1, y1)

plt.grid() # 격자
#plt.axis((np.min(x_train) - 1, np.max(x_train) + 1, np.min(y_train) - 1, np.max(y_train) + 1))
plt.title(str1)
# Out:
# Text(0.5, 1.0, 'y = 3.064975x + -0.13483758')

# %% [markdown]
# ### R-Squared-1

# %% [markdown]
# R-Squared란? 모델이 데이터에 얼마나 적합한 지 수치적으로 결정하는 방법입니다.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import random
# %matplotlib inline

# %% [markdown]
# ###MSE(Mean Squared Error)

# %% [markdown]
# **$$\frac{(실제값-예측값)^2}{데이터수}$$**

# %%
x=[[1],[2],[3],[4],[5]]
y=[[1],[5],[6],[7],[11]]
y=np.array(y)
x=np.array(x)
mean=(1+5+6+7+11)/5
print(y)
# Out:
# [[ 1]
#  [ 5]
#  [ 6]
#  [ 7]
#  [11]]

# %%
plt.plot(x, y, '.',linestyle='')    #plt.plot(x, y, maker='o',linestyle='')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
lr=LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.plot(x, y, '.',linestyle='')    #plt.plot(x, y, maker='o',linestyle='')
plt.plot(x,lr.predict(x),color = 'red')
plt.axhline(y=mean, xmin=0.04, xmax=0.96, color = 'black')

# %%
mean_squared_error(y,lr.predict(x))
# Out:
# 0.7200000000000001

# %%
print(lr.predict(x))
# Out:
# [[ 1.6]
#  [ 3.8]
#  [ 6. ]
#  [ 8.2]
#  [10.4]]

# %%
def myMSE(X, Y, line):
    err=0
    #for i in range(len(X)):        #예측값 MSE 구하기
    #         err +=(Y[i][0]-line[i][0])**2

    if (str(type(line)) == "<class 'float'>"): #평군 MSE 구하기
        for i in range(len(x)):
            err +=(Y[i][0]-line)**2
    else:
        for i in range(len(x)):      #예측값 MSE 구하기 
            err +=(Y[i][0]-line[i][0])**2

    MSE = err/len(X)
    return MSE

# %%
print("MSE : ", myMSE(x,y,lr.predict(x)))
# Out:
# MSE :  0.7200000000000001

# %% [markdown]
# ### R-Squared-2

# %% [markdown]
# **$$R^2 = 1-\frac{MSE of regression line}{MSE of the average of the data}$$**

# %%
lr.score(x, y)
# Out:
# 0.9307692307692308

# %%
def myRsq(X, Y, model):
    #평균 구하기
    hap = 0
    for i in range(len(x)):
        hap += Y[i][0]
    mean = float(hap/len(X))
    print("평균 : ",mean)

    #모델fit하기
    model.fit(X,Y)

    #MSE와 R-Squared구하기
    reg_mse=myMSE(X, Y, model.predict(X))
    avg_mse=myMSE(X, Y, mean)
    r=1-(reg_mse/avg_mse)

    #출력
    #print("MSE of regression line : ".reg_mse)
    #print("MSE of regression line : ".avg_mse)
    print("R-Squared : ", r)

# %%
myRsq(x, y, LinearRegression())
# Out:
# 평균 :  6.0
# R-Squared :  0.9307692307692308

# %% [markdown]
# ###100개 데이터로 해보기

# %% [markdown]
# 데이터가 선형모델에 적합한 경우

# %% [markdown]
# 1. 데이터 만들기

# %%
data=100 #데이터 개수 정하기

# %%
#x_train 데이터 만들기
x_train=[]
for i in range(1,data+1):
    x_train.append([i])

x_train=np.array(x_train)
x_train.shape
# Out:
# (100, 1)

# %%
#y_train 데이터 만들기
y_train1=[]
for i in range(1,data+1): #y_train에 노이즈를 만들어서 넣기
    y_train1.append([i+random.uniform(-20,20)]) #난수발생시켜서 노이즈 만들기

y_train1=np.array(y_train1)
y_train1.shape
# Out:
# (100, 1)

# %%
plt.plot(x_train, y_train1, '.',linestyle='')    #plt.plot(x_train, y_train1, maker='o',linestyle='')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# 2. 모델에 넣기

# %%
lr.fit(x_train,y_train1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#평균값 구하기
mean=0
for i in y_train1:
    for j in i:
        mean+=j
mean=mean/data
print(mean)
# Out:
# 48.818191284452034

# %%
#예측한 값과 평균 그려보기
plt.plot(x_train, y_train1, '.',linestyle='')   #plt.plot(x_train, y_train1, maker='o',linestyle='')
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(x_train,lr.predict(x_train),color = 'red')

# %% [markdown]
# 3. 함수와 내가 만든 함수 비교하기

# %%
lr.score(x_train,y_train1)
# Out:
# 0.8715767639802932

# %%
myRsq(x_train,y_train1, LinearRegression())
# Out:
# 평균 :  -0.23797568022783763
# R-Squared :  -0.0202695391241261

# %% [markdown]
# 데이터가 선형모델에 부적합한 경우

# %%
#y_train 데이터 만들기
y_train2=[]
for i in range(1,data+1): #y_train에 노이즈를 만들어서 넣기
    y_train2.append([i+random.uniform(-400,400)]) #난수발생시켜서 노이즈 만들기

y_train2=np.array(y_train2)
y_train2.shape
# Out:
# (100, 1)

# %%
plt.plot(x_train, y_train2, '.',linestyle='')   #plt.plot(x_train, y_train2, maker='o',linestyle='')
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(x_train,lr.predict(x_train),color = 'red') 
plt.axhline(y=mean, xmin=0.04, xmax=0.96, color = 'black')

# %%
lr.score(x_train,y_train2)
# Out:
# -0.047748535518785884

# %%
myRsq(x_train,y_train2, LinearRegression())
# Out:
# 평균 :  -0.8905674488400299
# R-Squared :  -0.19534382121687055
